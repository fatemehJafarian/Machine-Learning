# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
#load the data set
fashion_mnist = keras.datasets.fashion_mnist

#Split the data
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

#scale the values to a range 0 to 1
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
#Build the model
model = keras.Sequential([keras.layers.Flatten(input_shape = (28, 28)), 
                          keras.layers.Dense(100, activation='sigmoid'),
                          keras.layers.Dense(10, activation='softmax')])

#Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Fit th train data
history = model.fit(X_train, y_train, validation_split = 0.2, epochs = 10)

test_loss, test_acc = model.evaluate(X_test, y_test)

plt.plot(history.history['accuracy']) 
plt.plot(history.history['val_accuracy'])
plt.title('sigmoid activation function') 
plt.xlabel('epoch') 
plt.ylabel('accuracy') 
plt.legend(['train', 'validation'], loc='upper left') 
plt.show()

#Predict the test results
prediction = model.predict_classes(X_test)
length = len(prediction)
y_label = np.array(y_test)
predict_label = np.array(prediction)

print('Accuracy : ', accuracy_score(y_label,predict_label)*100)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5873 - accuracy: 0.8048 - val_loss: 0.4408 - val_accuracy: 0.8432
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4074 - accuracy: 0.8555 - val_loss: 0.3961 - val_accuracy: 0.8549
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3681 - accuracy: 0.8683 - val_loss: 0.3821 - val_accuracy: 0.8617
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3435 - accuracy: 0.8756 - val_loss: 0.3510 - val_accuracy: 0.8723
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3241 - accuracy: 0.8825 - val_loss: 0.3371 - val_accuracy: 0.8798
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3080 - accuracy: 0.8889 - val_loss: 0.3581 - val_accuracy: 0.8661
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2960 - accuracy: 0.8911 - val_loss: 0.3296 - val_accuracy: 0.8763
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2855 - accuracy: 0.8950 - val_loss: 0.3207 - val_accuracy: 0.8820
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2739 - accuracy: 0.8992 - val_loss: 0.3205 - val_accuracy: 0.8817
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2635 - accuracy: 0.9038 - val_loss: 0.3168 - val_accuracy: 0.8854
# 313/313 [==============================] - 0s 2ms/step - loss: 0.3444 - accuracy: 0.8774
# Accuracy :  87.74

# %%
#Build the model
model = keras.Sequential([keras.layers.Flatten(input_shape = (28, 28)), 
                          keras.layers.Dense(100, activation='relu'),
                          keras.layers.Dense(10, activation='softmax')])

#Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Fit th train data
history = model.fit(X_train, y_train, validation_split = 0.2, epochs = 10)

test_loss, test_acc = model.evaluate(X_test, y_test)

plt.plot(history.history['accuracy']) 
plt.plot(history.history['val_accuracy']) 
plt.title('relu activation function')
plt.xlabel('epoch') 
plt.ylabel('accuracy') 
plt.legend(['train', 'validation'], loc='upper left') 
plt.show()

#Predict the test results
prediction = model.predict_classes(X_test)
length = len(prediction)
y_label = np.array(y_test)
predict_label = np.array(prediction)

print('Accuracy : ', accuracy_score(y_label,predict_label)*100)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5214 - accuracy: 0.8184 - val_loss: 0.4394 - val_accuracy: 0.8443
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3915 - accuracy: 0.8592 - val_loss: 0.3672 - val_accuracy: 0.8679
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3507 - accuracy: 0.8723 - val_loss: 0.3585 - val_accuracy: 0.8683
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3278 - accuracy: 0.8806 - val_loss: 0.3520 - val_accuracy: 0.8726
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3062 - accuracy: 0.8866 - val_loss: 0.3456 - val_accuracy: 0.8758
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2920 - accuracy: 0.8914 - val_loss: 0.3397 - val_accuracy: 0.8791
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2774 - accuracy: 0.8976 - val_loss: 0.3405 - val_accuracy: 0.8810
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2679 - accuracy: 0.9014 - val_loss: 0.3251 - val_accuracy: 0.8836
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2551 - accuracy: 0.9039 - val_loss: 0.3330 - val_accuracy: 0.8847
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.2479 - accuracy: 0.9077 - val_loss: 0.3246 - val_accuracy: 0.8845
# 313/313 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.8763
# Accuracy :  87.63

# %% [markdown]
# Part B:

# %%
#Build the model
model = keras.Sequential([keras.layers.Flatten(input_shape = (28, 28)),
                          keras.layers.Dense(300, activation='relu'),
                          keras.layers.Dense(10, activation='softmax')])

#Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Fit th train data
history = model.fit(X_train, y_train, validation_split = 0.2, epochs = 20)

test_loss, test_acc = model.evaluate(X_test, y_test)

plt.plot(history.history['accuracy']) 
plt.plot(history.history['val_accuracy']) 
plt.title('relu activation function')
plt.xlabel('epoch') 
plt.ylabel('accuracy') 
plt.legend(['train', 'validation'], loc='upper left') 
plt.show()

#Predict the test results
prediction = model.predict_classes(X_test)
length = len(prediction)
y_label = np.array(y_test)
predict_label = np.array(prediction)

print('Accuracy : ', accuracy_score(y_label,predict_label)*100)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5004 - accuracy: 0.8230 - val_loss: 0.4045 - val_accuracy: 0.8564
# Epoch 2/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3715 - accuracy: 0.8656 - val_loss: 0.3705 - val_accuracy: 0.8677
# Epoch 3/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3331 - accuracy: 0.8777 - val_loss: 0.3485 - val_accuracy: 0.8726
# Epoch 4/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3099 - accuracy: 0.8870 - val_loss: 0.3313 - val_accuracy: 0.8811
# Epoch 5/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2889 - accuracy: 0.8929 - val_loss: 0.3224 - val_accuracy: 0.8796
# Epoch 6/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2739 - accuracy: 0.8967 - val_loss: 0.3213 - val_accuracy: 0.8842
# Epoch 7/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2598 - accuracy: 0.9040 - val_loss: 0.3255 - val_accuracy: 0.8832
# Epoch 8/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2486 - accuracy: 0.9063 - val_loss: 0.3253 - val_accuracy: 0.8838
# Epoch 9/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2381 - accuracy: 0.9114 - val_loss: 0.3178 - val_accuracy: 0.8882
# Epoch 10/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2285 - accuracy: 0.9138 - val_loss: 0.3148 - val_accuracy: 0.8887
# Epoch 11/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2195 - accuracy: 0.9178 - val_loss: 0.3317 - val_accuracy: 0.8834
# Epoch 12/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2131 - accuracy: 0.9218 - val_loss: 0.3268 - val_accuracy: 0.8855
# Epoch 13/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2018 - accuracy: 0.9232 - val_loss: 0.3344 - val_accuracy: 0.8888
# Epoch 14/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1945 - accuracy: 0.9282 - val_loss: 0.3216 - val_accuracy: 0.8931
# Epoch 15/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1917 - accuracy: 0.9293 - val_loss: 0.3282 - val_accuracy: 0.8917
# Epoch 16/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1834 - accuracy: 0.9322 - val_loss: 0.3449 - val_accuracy: 0.8909
# Epoch 17/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1796 - accuracy: 0.9325 - val_loss: 0.3485 - val_accuracy: 0.8911
# Epoch 18/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1706 - accuracy: 0.9362 - val_loss: 0.3292 - val_accuracy: 0.8952
# Epoch 19/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1666 - accuracy: 0.9375 - val_loss: 0.3407 - val_accuracy: 0.8936
# Epoch 20/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1602 - accuracy: 0.9402 - val_loss: 0.3559 - val_accuracy: 0.8907
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3809 - accuracy: 0.8859
# Accuracy :  88.59

# %%
#Build the model
model = keras.Sequential([keras.layers.Flatten(input_shape = (28, 28)),
                          keras.layers.Dropout(0.1), 
                          keras.layers.Dense(300, activation='relu'),
                          keras.layers.Dropout(0.1),
                          keras.layers.Dense(10, activation='softmax')])

#Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

#Fit th train data
history = model.fit(X_train, y_train, validation_split = 0.2, epochs = 20)

test_loss, test_acc = model.evaluate(X_test, y_test)

plt.plot(history.history['accuracy']) 
plt.plot(history.history['val_accuracy']) 
plt.title('relu activation function')
plt.xlabel('epoch') 
plt.ylabel('accuracy') 
plt.legend(['train', 'validation'], loc='upper left') 
plt.show()

#Predict the test results
prediction = model.predict_classes(X_test)
length = len(prediction)
y_label = np.array(y_test)
predict_label = np.array(prediction)

print('Accuracy : ', accuracy_score(y_label,predict_label)*100)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.5249 - accuracy: 0.8113 - val_loss: 0.4077 - val_accuracy: 0.8558
# Epoch 2/20
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.4030 - accuracy: 0.8533 - val_loss: 0.3782 - val_accuracy: 0.8631
# Epoch 3/20
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3610 - accuracy: 0.8658 - val_loss: 0.3773 - val_accuracy: 0.8616
# Epoch 4/20
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3432 - accuracy: 0.8733 - val_loss: 0.3534 - val_accuracy: 0.8755
# Epoch 5/20
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3246 - accuracy: 0.8793 - val_loss: 0.3771 - val_accuracy: 0.8614
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3141 - accuracy: 0.8834 - val_loss: 0.3290 - val_accuracy: 0.8813
# Epoch 7/20
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.3040 - accuracy: 0.8855 - val_loss: 0.3272 - val_accuracy: 0.8790
# Epoch 8/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2953 - accuracy: 0.8891 - val_loss: 0.3118 - val_accuracy: 0.8874
# Epoch 9/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2855 - accuracy: 0.8929 - val_loss: 0.3110 - val_accuracy: 0.8884
# Epoch 10/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2797 - accuracy: 0.8961 - val_loss: 0.3119 - val_accuracy: 0.8852
# Epoch 11/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2708 - accuracy: 0.8976 - val_loss: 0.3366 - val_accuracy: 0.8775
# Epoch 12/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2658 - accuracy: 0.9007 - val_loss: 0.3089 - val_accuracy: 0.8892
# Epoch 13/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2583 - accuracy: 0.9034 - val_loss: 0.3174 - val_accuracy: 0.8888
# Epoch 14/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2520 - accuracy: 0.9052 - val_loss: 0.3047 - val_accuracy: 0.8907
# Epoch 15/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2502 - accuracy: 0.9053 - val_loss: 0.3115 - val_accuracy: 0.8890
# Epoch 16/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2451 - accuracy: 0.9063 - val_loss: 0.3169 - val_accuracy: 0.8903
# Epoch 17/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2394 - accuracy: 0.9106 - val_loss: 0.3151 - val_accuracy: 0.8920
# Epoch 18/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2351 - accuracy: 0.9104 - val_loss: 0.3019 - val_accuracy: 0.8946
# Epoch 19/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2321 - accuracy: 0.9122 - val_loss: 0.3094 - val_accuracy: 0.8921
# Epoch 20/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2280 - accuracy: 0.9127 - val_loss: 0.3136 - val_accuracy: 0.8953
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3419 - accuracy: 0.8925
# Accuracy :  89.25
